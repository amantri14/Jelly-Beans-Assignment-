# %% [markdown]
# # GBA 465 Assignment 2 - Jelly Bellies (Starter)

# %% [markdown]
# - Part A - The Jelly Belly Flavors (5 Points)
# - Part B - The Jelly Belly Fan Club Members (5 Points)
# - Part C - The Bean Bags (10 Points)
# - Part D - The Promo Beans (5 Points)
# - Part E - All The Beans (5 Points)
# - Part F - The Trades (10 Points)
# - Part G - The Recipes (10 Points)
# - Part H - Initializing Recipe Counts (10 Points)
# - Part I - Making Recipes (20 Points)
# - Part J - Display Recipe Counts (10 Points)
# - Part K - The Final Results (10 Points)
#
#
# - Deductions for incorrect results or for using Python techniques not covered in Class 08 and prior.
# - No pseudocode/comments are needed.

# %% [markdown]
# ## Part A - The Jelly Belly Flavors
# Below is a `list` of popular Jelly Belly `flavors`.
#
# **Action:** Execute the following code block.

# %%
flavors = [ "Coconut", "Strawberry Cheesecake", "Green Apple", "Licorice", "Kiwi", "Berry Blue", "Dr. Pepper", "Sunkist Orange", "Chili Mango", "Pomegranate", "Sunkist Lime", "Caramel Corn", "Cappuccino", "French Vanilla", "Red Apple", "Very Cherry", "Buttered Popcorn", "Lemon Drop", "Orange Sherbet", "Tutti-Fruitti", "Sunkist Lemon", "Sunkist Tangerine", "Strawberry Daiquiri", "Plum", "Sizzling Cinnamon", "Margarita", "A&W Cream Soda", "Cotton Candy", "Island Punch", "Raspberry", "Strawberry Jam", "Bubble Gum", "Lemon Lime", "Top Banana", "Cinnamon", "Peach", "Crushed Pineapple", "Watermelon", "A&W Root Beer", "Blueberry", "Sunkist Pink Grapefruit", "Mango", "Pina Colada", "Juicy Pear", "Mixed Berry Smoothie", "Toasted Marshmallow", "Chocolate Pudding", "Wild Blackberry", "Sour Cherry", "Cantaloupe" ]

# %% [markdown]
# **Actions:**
#
# - Sort `flavors` alphabetically by name.
# - Convert the sorted list `flavors` into a tuple.
# - Reassign the `tuple` back into the `flavors` variable.
# - Using a `while` loop along with a counter variable, output each flavor in `flavors` out on a separate line, along with a one-based count.  Example:
#
# ```
# 1. A&W Cream Soda
# 2. A&W Root Beer
# ...
# 49. Watermelon
# 50. Wild Blackberry
# ```

# %%
# Your Part A implementation:

sorted_flavors = sorted(flavors)
sorted_flavors_tuple = tuple(sorted_flavors)
flavors = sorted_flavors_tuple
counter = 1
while counter <= len(flavors):
    print("{}. {}".format(counter, flavors[counter-1]))
    counter += 1
# Out:
# 1. A&W Cream Soda
# 2. A&W Root Beer
# 3. Berry Blue
# 4. Blueberry
# 5. Bubble Gum
# 6. Buttered Popcorn
# 7. Cantaloupe
# 8. Cappuccino
# 9. Caramel Corn
# 10. Chili Mango
# 11. Chocolate Pudding
# 12. Cinnamon
# 13. Coconut
# 14. Cotton Candy
# 15. Crushed Pineapple
# 16. Dr. Pepper
# 17. French Vanilla
# 18. Green Apple
# 19. Island Punch
# 20. Juicy Pear
# 21. Kiwi
# 22. Lemon Drop
# 23. Lemon Lime
# 24. Licorice
# 25. Mango
# 26. Margarita
# 27. Mixed Berry Smoothie
# 28. Orange Sherbet
# 29. Peach
# 30. Pina Colada
# 31. Plum
# 32. Pomegranate
# 33. Raspberry
# 34. Red Apple
# 35. Sizzling Cinnamon
# 36. Sour Cherry
# 37. Strawberry Cheesecake
# 38. Strawberry Daiquiri
# 39. Strawberry Jam
# 40. Sunkist Lemon
# 41. Sunkist Lime
# 42. Sunkist Orange
# 43. Sunkist Pink Grapefruit
# 44. Sunkist Tangerine
# 45. Toasted Marshmallow
# 46. Top Banana
# 47. Tutti-Fruitti
# 48. Very Cherry
# 49. Watermelon
# 50. Wild Blackberry

# %% [markdown]
# ## Part B - The Jelly Belly Fan Club Members
#
# There are three University of Rochester students in local chapter of the Jelly Belly Fan Club: Clara, Ben, and Alex.
#
# They love Jelly Bellies!
#
# **Actions:**
# - Create a `list` named `memberNames` which contains the names "Clara", "Ben", and "Alex", in that order.
# - Sort `memberNames` alphabetically by name.
# - Convert the sorted list `memberNames` into a `tuple`.
# - Reassign the `tuple` back into the `memberNames` variable.
# - Using a `for` loop, print each name in `memberNames` out on a separate line.

# %%
# Your Part B implementation: 

memberNames = ["Clara", "Ben", "Alex"]
memberNames.sort()
memberNames_tuple = tuple(memberNames)
memberNames = memberNames_tuple

for name in memberNames:
    print(name)
# Out:
# Alex
# Ben
# Clara

# %% [markdown]
# ## Part C - The Bean Bags
#
# As a club event, the Jelly Belly Fan Club Members went to store, where each member bought an oversized bag of assorted Jelly Belly jelly beans.
#
# Jelly Belly corporate quality control tells us that each bag contains between 20-50 beans for each flavor in `flavors`.
#
# That's a lot of beans in each bag!

# %% [markdown]
# **Action:** Create a blank `dictionary` called `beanBags` that will hold all the contents of each bag.

# %%
# Your implementation:
beanBags = {}

# %% [markdown]
# The members returned to their club room to sort and count their beans by flavor.
#
# Below are the results.
#
# **Action:** Execute the following code block.

# %%
alexBeans = { 'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 23, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 38, 'Green Apple': 36, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 45, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 26, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23 }
benBeans = { 'A&W Cream Soda': 46, 'A&W Root Beer': 33, 'Berry Blue': 24, 'Blueberry': 44, 'Bubble Gum': 46, 'Buttered Popcorn': 38, 'Cantaloupe': 48, 'Cappuccino': 46, 'Caramel Corn': 39, 'Chili Mango': 41, 'Chocolate Pudding': 29, 'Cinnamon': 26, 'Coconut': 25, 'Cotton Candy': 45, 'Crushed Pineapple': 30, 'Dr. Pepper': 32, 'French Vanilla': 43, 'Green Apple': 20, 'Island Punch': 33, 'Juicy Pear': 20, 'Kiwi': 41, 'Lemon Drop': 26, 'Lemon Lime': 48, 'Licorice': 50, 'Mango': 41, 'Margarita': 37, 'Mixed Berry Smoothie': 42, 'Orange Sherbet': 31, 'Peach': 47, 'Pina Colada': 46, 'Plum': 47, 'Pomegranate': 25, 'Raspberry': 45, 'Red Apple': 37, 'Sizzling Cinnamon': 48, 'Sour Cherry': 40, 'Strawberry Cheesecake': 21, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 32, 'Sunkist Lemon': 20, 'Sunkist Lime': 20, 'Sunkist Orange': 40, 'Sunkist Pink Grapefruit': 32, 'Sunkist Tangerine': 49, 'Toasted Marshmallow': 34, 'Top Banana': 34, 'Tutti-Fruitti': 38, 'Very Cherry': 27, 'Watermelon': 38, 'Wild Blackberry': 31 }
claraBeans = { 'A&W Cream Soda': 32, 'A&W Root Beer': 25, 'Berry Blue': 33, 'Blueberry': 27, 'Bubble Gum': 45, 'Buttered Popcorn': 46, 'Cantaloupe': 35, 'Cappuccino': 30, 'Caramel Corn': 43, 'Chili Mango': 40, 'Chocolate Pudding': 34, 'Cinnamon': 32, 'Coconut': 29, 'Cotton Candy': 42, 'Crushed Pineapple': 44, 'Dr. Pepper': 25, 'French Vanilla': 47, 'Green Apple': 45, 'Island Punch': 27, 'Juicy Pear': 30, 'Kiwi': 33, 'Lemon Drop': 21, 'Lemon Lime': 38, 'Licorice': 22, 'Mango': 29, 'Margarita': 27, 'Mixed Berry Smoothie': 48, 'Orange Sherbet': 21, 'Peach': 46, 'Pina Colada': 31, 'Plum': 47, 'Pomegranate': 46, 'Raspberry': 40, 'Red Apple': 32, 'Sizzling Cinnamon': 32, 'Sour Cherry': 28, 'Strawberry Cheesecake': 30, 'Strawberry Daiquiri': 31, 'Strawberry Jam': 47, 'Sunkist Lemon': 47, 'Sunkist Lime': 44, 'Sunkist Orange': 32, 'Sunkist Pink Grapefruit': 49, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 31, 'Top Banana': 41, 'Tutti-Fruitti': 49, 'Very Cherry': 40, 'Watermelon': 32, 'Wild Blackberry': 30 }

# %% [markdown]
# **Actions:**
#
# - Add Alex's Jelly Belly counts from `alexBeans` to the `beanBags` dictionary, using `Alex` as the key.
# - Add Ben's Jelly Belly counts from `benBeans` to the `beanBags` dictionary, using `Ben` as the key.
# - Add Clara's Jelly Belly counts from `claraBeans` to the `beanBags` dictionary, using `Clara` as the key.
# - From the `beanBags` dictionary, use a `for` loop with both `key` and a `value` iterator variables.
# - For each member:
#     1. Print the key (the member's name)
#     2. Print the value (the member's Jelly Bellies as a dictionary)

# %%
# Your implementation:
beanBags['Alex'] = alexBeans
beanBags['Ben'] = benBeans
beanBags['Clara'] = claraBeans

for member_name, beans in beanBags.items():
    print(member_name + ":")
    for flavor, count in beans.items():
        print("  " + flavor + ": " + str(count))
    print()
# Out:
# Alex:
#   A&W Cream Soda: 24
#   A&W Root Beer: 50
#   Berry Blue: 49
#   Blueberry: 25
#   Bubble Gum: 37
#   Buttered Popcorn: 27
#   Cantaloupe: 25
#   Cappuccino: 36
#   Caramel Corn: 36
#   Chili Mango: 29
#   Chocolate Pudding: 49
#   Cinnamon: 23
#   Coconut: 27
#   Cotton Candy: 25
#   Crushed Pineapple: 21
#   Dr. Pepper: 21
#   French Vanilla: 38
#   Green Apple: 36
#   Island Punch: 31
#   Juicy Pear: 40
#   Kiwi: 38
#   Lemon Drop: 27
#   Lemon Lime: 42
#   Licorice: 30
#   Mango: 41
#   Margarita: 42
#   Mixed Berry Smoothie: 24
#   Orange Sherbet: 20
#   Peach: 43
#   Pina Colada: 33
#   Plum: 20
#   Pomegranate: 35
#   Raspberry: 41
#   Red Apple: 45
#   Sizzling Cinnamon: 29
#   Sour Cherry: 48
#   Strawberry Cheesecake: 40
#   Strawberry Daiquiri: 23
#   Strawberry Jam: 42
#   Sunkist Lemon: 44
#   Sunkist Lime: 26
#   Sunkist Orange: 45
#   Sunkist Pink Grapefruit: 27
#   Sunkist Tangerine: 22
#   Toasted Marshmallow: 42
#   Top Banana: 22
#   Tutti-Fruitti: 30
#   Very Cherry: 28
#   Watermelon: 33
#   Wild Blackberry: 23
#
# Ben:
#   A&W Cream Soda: 46
#   A&W Root Beer: 33
#   Berry Blue: 24
#   Blueberry: 44
#   Bubble Gum: 46
#   Buttered Popcorn: 38
#   Cantaloupe: 48
#   Cappuccino: 46
#   Caramel Corn: 39
#   Chili Mango: 41
#   Chocolate Pudding: 29
#   Cinnamon: 26
#   Coconut: 25
#   Cotton Candy: 45
#   Crushed Pineapple: 30
#   Dr. Pepper: 32
#   French Vanilla: 43
#   Green Apple: 20
#   Island Punch: 33
#   Juicy Pear: 20
#   Kiwi: 41
#   Lemon Drop: 26
#   Lemon Lime: 48
#   Licorice: 50
#   Mango: 41
#   Margarita: 37
#   Mixed Berry Smoothie: 42
#   Orange Sherbet: 31
#   Peach: 47
#   Pina Colada: 46
#   Plum: 47
#   Pomegranate: 25
#   Raspberry: 45
#   Red Apple: 37
#   Sizzling Cinnamon: 48
#   Sour Cherry: 40
#   Strawberry Cheesecake: 21
#   Strawberry Daiquiri: 34
#   Strawberry Jam: 32
#   Sunkist Lemon: 20
#   Sunkist Lime: 20
#   Sunkist Orange: 40
#   Sunkist Pink Grapefruit: 32
#   Sunkist Tangerine: 49
#   Toasted Marshmallow: 34
#   Top Banana: 34
#   Tutti-Fruitti: 38
#   Very Cherry: 27
#   Watermelon: 38
#   Wild Blackberry: 31
#
# Clara:
#   A&W Cream Soda: 32
#   A&W Root Beer: 25
#   Berry Blue: 33
#   Blueberry: 27
#   Bubble Gum: 45
#   Buttered Popcorn: 46
#   Cantaloupe: 35
#   Cappuccino: 30
#   Caramel Corn: 43
#   Chili Mango: 40
#   Chocolate Pudding: 34
#   Cinnamon: 32
#   Coconut: 29
#   Cotton Candy: 42
#   Crushed Pineapple: 44
#   Dr. Pepper: 25
#   French Vanilla: 47
#   Green Apple: 45
#   Island Punch: 27
#   Juicy Pear: 30
#   Kiwi: 33
#   Lemon Drop: 21
#   Lemon Lime: 38
#   Licorice: 22
#   Mango: 29
#   Margarita: 27
#   Mixed Berry Smoothie: 48
#   Orange Sherbet: 21
#   Peach: 46
#   Pina Colada: 31
#   Plum: 47
#   Pomegranate: 46
#   Raspberry: 40
#   Red Apple: 32
#   Sizzling Cinnamon: 32
#   Sour Cherry: 28
#   Strawberry Cheesecake: 30
#   Strawberry Daiquiri: 31
#   Strawberry Jam: 47
#   Sunkist Lemon: 47
#   Sunkist Lime: 44
#   Sunkist Orange: 32
#   Sunkist Pink Grapefruit: 49
#   Sunkist Tangerine: 30
#   Toasted Marshmallow: 31
#   Top Banana: 41
#   Tutti-Fruitti: 49
#   Very Cherry: 40
#   Watermelon: 32
#   Wild Blackberry: 30

# %% [markdown]
# **Action:**
#
# - Access and print out the following values:
#
#     1. How many "Bubble Gum" beans does Alex have?
#     2. How many *more* "Watermelon" beans does Ben have compared to Clara?
#     3. How many "Mixed Berry Smoothie" beans does Clara have?

# %%
# Your implementation:

bubble_gum_alex = alexBeans['Bubble Gum']
watermelon_difference = benBeans['Watermelon'] - claraBeans['Watermelon']
mixed_berry_clara = claraBeans['Mixed Berry Smoothie']

bubble_gum_alex, watermelon_difference, mixed_berry_clara


print("Alex has {} 'Bubble Gum' beans.".format(alexBeans['Bubble Gum']))
print("Ben has {} more 'Watermelon' beans compared to Clara.".format(benBeans['Watermelon'] - claraBeans['Watermelon']))
print("Clara has {} 'Mixed Berry Smoothie' beans.".format(claraBeans['Mixed Berry Smoothie']))
# Out:
# Alex has 37 'Bubble Gum' beans.
# Ben has 6 more 'Watermelon' beans compared to Clara.
# Clara has 48 'Mixed Berry Smoothie' beans.

# %% [markdown]
# ## Part D - The Promo Beans
#
# When checking out at the store, each member received a free, promotional ("promo") bag of Jelly Bellies.
#
# Each promo bag has exactly 200 beans, and each promo bag has the exact same flavors and flavor quantity of beans.
#
# Alex inventoried the flavors in the promo bag, listing each flavor separately.  Below are the results.
#
# **Action:** Execute the following code block.

# %%
promoBeans = ('French Vanilla', 'Green Apple', 'Cinnamon', 'Red Apple', 'Sunkist Lime', 'Licorice', 'Blueberry', 'Sunkist Lemon', 'Plum', 'Pina Colada', 'Bubble Gum', 'Strawberry Cheesecake', 'French Vanilla', 'Coconut', 'Licorice', 'Caramel Corn', 'Strawberry Cheesecake', 'Cinnamon', 'Cappuccino', 'Pina Colada', 'French Vanilla', 'Very Cherry', 'Lemon Drop', 'Blueberry', 'Dr. Pepper', 'Watermelon', 'Plum', 'Kiwi', 'Sizzling Cinnamon', 'Pina Colada', 'A&W Root Beer', 'Kiwi', 'A&W Cream Soda', 'Buttered Popcorn', 'Strawberry Cheesecake', 'Peach', 'Sunkist Lemon', 'Blueberry', 'Bubble Gum', 'Blueberry', 'Cinnamon', 'Cappuccino', 'Cotton Candy', 'Berry Blue', 'Tutti-Fruitti', 'Pomegranate', 'Toasted Marshmallow', 'Caramel Corn', 'Watermelon', 'Red Apple', 'Pomegranate', 'Cinnamon', 'Sunkist Lime', 'Cantaloupe', 'Margarita', 'Toasted Marshmallow', 'Sunkist Lime', 'Strawberry Daiquiri', 'Cappuccino', 'A&W Cream Soda', 'Juicy Pear', 'Green Apple', 'Strawberry Cheesecake', 'Red Apple', 'Mango', 'Chili Mango', 'Sizzling Cinnamon', 'Blueberry', 'Chili Mango', 'Plum', 'Cotton Candy', 'Cappuccino', 'Sizzling Cinnamon', 'Caramel Corn', 'Top Banana', 'Sunkist Lime', 'Buttered Popcorn', 'Pina Colada', 'Peach', 'Berry Blue', 'Sunkist Lime', 'Strawberry Jam', 'Berry Blue', 'Licorice', 'A&W Cream Soda', 'Strawberry Jam', 'Tutti-Fruitti', 'Peach', 'Coconut', 'Tutti-Fruitti', 'Mixed Berry Smoothie', 'Watermelon', 'Sunkist Pink Grapefruit', 'Licorice', 'Toasted Marshmallow', 'Coconut', 'Caramel Corn', 'Green Apple', 'Juicy Pear', 'Coconut', 'Island Punch', 'Sizzling Cinnamon', 'Caramel Corn', 'Cantaloupe', 'Berry Blue', 'Lemon Drop', 'Crushed Pineapple', 'Cotton Candy', 'Blueberry', 'Strawberry Daiquiri', 'Strawberry Jam', 'Lemon Drop', 'Caramel Corn', 'Licorice', 'Very Cherry', 'Raspberry', 'Toasted Marshmallow', 'Watermelon', 'Red Apple', 'Toasted Marshmallow', 'Sunkist Pink Grapefruit', 'Strawberry Daiquiri', 'Sour Cherry', 'Red Apple', 'Tutti-Fruitti', 'Mango', 'A&W Cream Soda', 'A&W Cream Soda', 'Dr. Pepper', 'Very Cherry', 'Toasted Marshmallow', 'Blueberry', 'Chocolate Pudding', 'Sunkist Lemon', 'Red Apple', 'A&W Cream Soda', 'Dr. Pepper', 'Pomegranate', 'Watermelon', 'Strawberry Jam', 'Sunkist Lime', 'Plum', 'Top Banana', 'Lemon Lime', 'Very Cherry', 'Wild Blackberry', 'Chocolate Pudding', 'Pomegranate', 'Peach', 'Bubble Gum', 'Coconut', 'Bubble Gum', 'Strawberry Jam', 'Cappuccino', 'Pina Colada', 'Strawberry Jam', 'Cantaloupe', 'Cotton Candy', 'French Vanilla', 'Sunkist Pink Grapefruit', 'Berry Blue', 'Raspberry', 'Berry Blue', 'Caramel Corn', 'A&W Root Beer', 'Kiwi', 'Pina Colada', 'Cotton Candy', 'Red Apple', 'A&W Cream Soda', 'Sizzling Cinnamon', 'Coconut', 'Wild Blackberry', 'A&W Cream Soda', 'Orange Sherbet', 'Sour Cherry', 'Watermelon', 'Caramel Corn', 'Orange Sherbet', 'Green Apple', 'Wild Blackberry', 'Bubble Gum', 'Sunkist Orange', 'Sunkist Pink Grapefruit', 'Tutti-Fruitti', 'Red Apple', 'Lemon Drop', 'Sizzling Cinnamon', 'Strawberry Cheesecake', 'Caramel Corn', 'Sunkist Pink Grapefruit', 'Lemon Lime', 'Green Apple', 'Buttered Popcorn', 'Lemon Lime', 'Juicy Pear', 'Plum', 'Watermelon', 'Sunkist Pink Grapefruit', 'Pomegranate')

# %% [markdown]
# **Action:** Adjust (increment) each member's bean totals based on their promo bag.
#
# Notes/Hints on your adjustment algorithm:
# - Each item/flavor in the `promoBeans` tuple represents one(1) bean of that flavor.
# - You may want to use a nested `for` loop.
# - The first/outer `for` loop iterates over the memberNames.
# - The second/inner `for` loop iterates over the promoBeans.
# - Inside the inner loop, add one(1) bean to the current flavor total for the current member.

# %%
# Your implementation:

for member, beans in beanBags.items():
    for promo_flavor in promoBeans:
        if promo_flavor in beans:
            beans[promo_flavor] += 1
        else:
            beans[promo_flavor] = 1
        print(member+str(beans)+'\n')
# Out:
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 23, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 36, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 45, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 26, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 23, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 45, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 26, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 45, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 26, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 26, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 30, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 25, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 44, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 20, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 33, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 37, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 40, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 39, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 41, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 27, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 41, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 31, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 41, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 36, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 41, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 41, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 24, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 36, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 34, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 40, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 28, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 27, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 26, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 21, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 33, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 21, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 38, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 39, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 29, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 39, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 35, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 50, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 39, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 39, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 24, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 27, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 42, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 43, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 45, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 27, 'Bubble Gum': 38, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 28, 'Bubble Gum': 38, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 28, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 25, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 37, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 25, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 49, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 26, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 50, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 26, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 30, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 50, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 26, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 35, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 31, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 50, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 26, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 36, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 42, 'Top Banana': 22, 'Tutti-Fruitti': 31, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# Alex{'A&W Cream Soda': 25, 'A&W Root Beer': 51, 'Berry Blue': 50, 'Blueberry': 29, 'Bubble Gum': 39, 'Buttered Popcorn': 28, 'Cantaloupe': 25, 'Cappuccino': 38, 'Caramel Corn': 37, 'Chili Mango': 29, 'Chocolate Pudding': 49, 'Cinnamon': 26, 'Coconut': 28, 'Cotton Candy': 26, 'Crushed Pineapple': 21, 'Dr. Pepper': 22, 'French Vanilla': 41, 'Green Apple': 37, 'Island Punch': 31, 'Juicy Pear': 40, 'Kiwi': 40, 'Lemon Drop': 28, 'Lemon Lime': 42, 'Licorice': 32, 'Mango': 41, 'Margarita': 42, 'Mixed Berry Smoothie': 24, 'Orange Sherbet': 20, 'Peach': 44, 'Pina Colada': 36, 'Plum': 22, 'Pomegranate': 36, 'Raspberry': 41, 'Red Apple': 46, 'Sizzling Cinnamon': 30, 'Sour Cherry': 48, 'Strawberry Cheesecake': 43, 'Strawberry Daiquiri': 23, 'Strawberry Jam': 42, 'Sunkist Lemon': 46, 'Sunkist Lime': 27, 'Sunkist Orange': 45, 'Sunkist Pink Grapefruit': 27, 'Sunkist Tangerine': 22, 'Toasted Marshmallow': 43, 'Top Banana': 22, 'Tutti-Fruitti': 31, 'Very Cherry': 29, 'Watermelon': 34, 'Wild Blackberry': 23}
#
# ...
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 51, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 24, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 37, 'Sour Cherry': 30, 'Strawberry Cheesecake': 34, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 53, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 51, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 37, 'Sour Cherry': 30, 'Strawberry Cheesecake': 34, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 53, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 51, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 34, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 53, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 51, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 53, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 53, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 39, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 49, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 40, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 48, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 40, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 40, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 32, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 33, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 51, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 33, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 52, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 38, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 33, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 52, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 54, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 39, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 33, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 52, 'Pomegranate': 50, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 55, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 39, 'Wild Blackberry': 33}
#
# Clara{'A&W Cream Soda': 40, 'A&W Root Beer': 27, 'Berry Blue': 39, 'Blueberry': 34, 'Bubble Gum': 50, 'Buttered Popcorn': 49, 'Cantaloupe': 38, 'Cappuccino': 35, 'Caramel Corn': 52, 'Chili Mango': 42, 'Chocolate Pudding': 36, 'Cinnamon': 36, 'Coconut': 35, 'Cotton Candy': 47, 'Crushed Pineapple': 45, 'Dr. Pepper': 28, 'French Vanilla': 51, 'Green Apple': 50, 'Island Punch': 28, 'Juicy Pear': 33, 'Kiwi': 36, 'Lemon Drop': 25, 'Lemon Lime': 41, 'Licorice': 27, 'Mango': 31, 'Margarita': 28, 'Mixed Berry Smoothie': 49, 'Orange Sherbet': 23, 'Peach': 50, 'Pina Colada': 37, 'Plum': 52, 'Pomegranate': 51, 'Raspberry': 42, 'Red Apple': 40, 'Sizzling Cinnamon': 38, 'Sour Cherry': 30, 'Strawberry Cheesecake': 35, 'Strawberry Daiquiri': 34, 'Strawberry Jam': 53, 'Sunkist Lemon': 50, 'Sunkist Lime': 50, 'Sunkist Orange': 33, 'Sunkist Pink Grapefruit': 55, 'Sunkist Tangerine': 30, 'Toasted Marshmallow': 37, 'Top Banana': 43, 'Tutti-Fruitti': 54, 'Very Cherry': 44, 'Watermelon': 39, 'Wild Blackberry': 33}

# %% [markdown]
# **Actions:**
#
# - Access and print out the following values:
#
#     1. Now, how many "Bubble Gum" beans does Alex have?
#     2. Now, how many *more* "Watermelon" beans does Ben have compared to Clara?
#     3. Now, how many "Mixed Berry Smoothie" beans does Clara have?

# %%
# Your implementation:

bubble_gum_alex = beanBags['Alex']['Bubble Gum']
print("Now, Alex has {} 'Bubble Gum' beans.".format(bubble_gum_alex))

watermelon_difference = beanBags['Ben']['Watermelon'] - beanBags['Clara']['Watermelon']
print("Now, Ben has {} more 'Watermelon' beans compared to Clara.".format(watermelon_difference))


mixed_berry_clara = beanBags['Clara']['Mixed Berry Smoothie']
print("Now, Clara has {} 'Mixed Berry Smoothie' beans.".format(mixed_berry_clara))
# Out:
# Now, Alex has 42 'Bubble Gum' beans.
# Now, Ben has 6 more 'Watermelon' beans compared to Clara.
# Now, Clara has 49 'Mixed Berry Smoothie' beans.

# %% [markdown]
# ## Part E - All The Beans
# **Actions:**
#
# - Using a `for` loop and the `memberNames` list, how many total Lemon Lime beans would the members have if they pooled all their beans together?
# - **Do not** reference "Alex", "Ben", or "Clara" as a hard-coded string.  There is a more dynamic way to do this using the loop.
# - You may use a hard-coded string for "Lemon Lime".
# - Store the result in a variable called `totalLemonLimeAllMembers`.
# - Output `totalLemonLimeAllMembers` to the screen.

# %%
# Your implementation:

totalLemonLimeAllMembers = 0

for member, beans in beanBags.items():
    if "Lemon Lime" in beans:
        totalLemonLimeAllMembers += beans["Lemon Lime"]

print("Total 'Lemon Lime' beans all members have: {}".format(totalLemonLimeAllMembers))
# Out:
# Total 'Lemon Lime' beans all members have: 137

# %% [markdown]
# **Action:** If all the members pooled **all** their beans together, how many total beans would they have?
#
# - Use a nested `for` loop.
# - **Do not** reference any member name or flavor with a hard-coded string.
# - Store your result in `totalBeansAllMembers`.
# - Output `totalBeansAllMembers` to the screen.

# %%
# Your implementation:

totalBeansAllMembers = 0

for member, beans in beanBags.items():
    for flavor, count in beans.items():
        totalBeansAllMembers += count

print("Total beans all members have: {}".format(totalBeansAllMembers))
# Out:
# Total beans all members have: 5848

# %% [markdown]
# ## Part F - The Trades
#
# Alex and Ben like to trade Jelly Bellies so each gets more of their favorite flavors.
#
# ### The First Trade
#
# Alex gives Ben five(5) of his "Pina Colada" beans in exchange for five(5) of Ben's "Margarita" beans.
#
# This is an even trade!
#
# **Action:** Adjust the values for both Alex's and Ben's beans due to this trade.
#
# - Note: You may use hard-coded string values for list, tuple, or dictionary access.

# %%
# Your implementation:

beanBags['Alex']['Pina Colada'] -= 5
beanBags['Ben']['Pina Colada'] += 5

beanBags['Ben']['Margarita'] -= 5
beanBags['Alex']['Margarita'] += 5

print("After the trade:")
print("Alex's 'Pina Colada' beans:", beanBags['Alex']['Pina Colada'])
print("Ben's 'Pina Colada' beans:", beanBags['Ben']['Pina Colada'])
print("Alex's 'Margarita' beans:", beanBags['Alex']['Margarita'])
print("Ben's 'Margarita' beans:", beanBags['Ben']['Margarita'])
# Out:
# After the trade:
# Alex's 'Pina Colada' beans: 34
# Ben's 'Pina Colada' beans: 57
# Alex's 'Margarita' beans: 48
# Ben's 'Margarita' beans: 33

# %% [markdown]
# ### The Second Trade
# Clara also wants to make a trade and get more of her favorite flavors!
#
# Clara and Alex swap all their "A&W Root Beer" beans.
#
# Since Alex has a lot more "A&W Root Beer" beans than Clara, to make the trade fair, Clara also gives Alex twenty-five (25) of her "Chocolate Pudding" beans.
#
# **Action:** Adjust the values for both Clara's and Alex's beans due to this trade.
#
# - Note: You may use hard-coded string values for list, tuple, or dictionary access.

# %%
# Your implementation:

clara_root_beer = beanBags['Clara']['A&W Root Beer']
alex_root_beer = beanBags['Alex']['A&W Root Beer']

beanBags['Clara']['A&W Root Beer'] = alex_root_beer
beanBags['Alex']['A&W Root Beer'] = clara_root_beer

beanBags['Clara']['Chocolate Pudding'] -= 25
beanBags['Alex']['Chocolate Pudding'] += 25

print("After the trade:")
print("Clara's 'A&W Root Beer' beans:", beanBags['Clara']['A&W Root Beer'])
print("Alex's 'A&W Root Beer' beans:", beanBags['Alex']['A&W Root Beer'])
print("Clara's 'Chocolate Pudding' beans:", beanBags['Clara']['Chocolate Pudding'])
print("Alex's 'Chocolate Pudding' beans:", beanBags['Alex']['Chocolate Pudding'])
# Out:
# After the trade:
# Clara's 'A&W Root Beer' beans: 52
# Alex's 'A&W Root Beer' beans: 27
# Clara's 'Chocolate Pudding' beans: 11
# Alex's 'Chocolate Pudding' beans: 76

# %% [markdown]
# ### Check on Alex's Beans Post-Trades
# **Action:** Now that the trades are over, calculate the total number of beans that Alex has in his bag.
#
# - Store the value in `totalBeansAlex`.
# - Output `totalBeansAlex` to the screen.
# - Note: You may use hard-coded string values for list, tuple, or dictionary access.

# %%
# Your implementation:
totalBeansAlex = 0

for count in beanBags['Alex'].values():
    totalBeansAlex += count

print("Total beans Alex has post-trades: {}".format(totalBeansAlex))
# Out:
# Total beans Alex has post-trades: 1854

# %% [markdown]
# ### Display Final Bean Totals
#
# **Action:** Create a table showing the counts of each bean flavor for each of the Jelly Belly Fan Club members.
#
# - Use the `tabulate` Python package to achieve column-based layout.
# - Column 1: Flavor (display the flavor name of the bean)
# - Column 2: Alex (display the number of beans of this flavor belonging to Alex)
# - Column 3: Ben (display the number of beans of this flavor belonging to Ben)
# - Column 4: Clara (display the number of beans of this flavor belonging to Clara)
# - Do not use hard-coded strings for flavor names.
# - Do not use hard-coded strings for member names.

# %%
# Your implementation:

from tabulate import tabulate


flavors = []
for member in beanBags.values():
    for flavor in member:
        if flavor not in flavors:
            flavors.append(flavor)

flavors.sort()

table_data = []
for flavor in flavors:
    row = [flavor]
    for member in ['Alex', 'Ben', 'Clara']:
        row.append(beanBags[member][flavor] if flavor in beanBags[member] else 0)
    table_data.append(row)

headers = ['Flavor', 'Alex', 'Ben', 'Clara']

print(tabulate(table_data, headers=headers, tablefmt='grid'))
# Out:
# +-------------------------+--------+-------+---------+
# | Flavor                  |   Alex |   Ben |   Clara |
# +=========================+========+=======+=========+
# | A&W Cream Soda          |     32 |    54 |      40 |
# +-------------------------+--------+-------+---------+
# | A&W Root Beer           |     27 |    35 |      52 |
# +-------------------------+--------+-------+---------+
# | Berry Blue              |     55 |    30 |      39 |
# +-------------------------+--------+-------+---------+
# | Blueberry               |     32 |    51 |      34 |
# +-------------------------+--------+-------+---------+
# | Bubble Gum              |     42 |    51 |      50 |
# +-------------------------+--------+-------+---------+
# | Buttered Popcorn        |     30 |    41 |      49 |
# +-------------------------+--------+-------+---------+
# | Cantaloupe              |     28 |    51 |      38 |
# +-------------------------+--------+-------+---------+
# | Cappuccino              |     41 |    51 |      35 |
# +-------------------------+--------+-------+---------+
# | Caramel Corn            |     45 |    48 |      52 |
# +-------------------------+--------+-------+---------+
# | Chili Mango             |     31 |    43 |      42 |
# +-------------------------+--------+-------+---------+
# | Chocolate Pudding       |     76 |    31 |      11 |
# +-------------------------+--------+-------+---------+
# | Cinnamon                |     27 |    30 |      36 |
# +-------------------------+--------+-------+---------+
# | Coconut                 |     33 |    31 |      35 |
# +-------------------------+--------+-------+---------+
# | Cotton Candy            |     30 |    50 |      47 |
# +-------------------------+--------+-------+---------+
# | Crushed Pineapple       |     22 |    31 |      45 |
# +-------------------------+--------+-------+---------+
# | Dr. Pepper              |     24 |    35 |      28 |
# +-------------------------+--------+-------+---------+
# | French Vanilla          |     42 |    47 |      51 |
# +-------------------------+--------+-------+---------+
# | Green Apple             |     41 |    25 |      50 |
# +-------------------------+--------+-------+---------+
# | Island Punch            |     32 |    34 |      28 |
# +-------------------------+--------+-------+---------+
# | Juicy Pear              |     43 |    23 |      33 |
# +-------------------------+--------+-------+---------+
# | Kiwi                    |     41 |    44 |      36 |
# +-------------------------+--------+-------+---------+
# | Lemon Drop              |     31 |    30 |      25 |
# +-------------------------+--------+-------+---------+
# | Lemon Lime              |     45 |    51 |      41 |
# +-------------------------+--------+-------+---------+
# | Licorice                |     35 |    55 |      27 |
# +-------------------------+--------+-------+---------+
# | Mango                   |     43 |    43 |      31 |
# +-------------------------+--------+-------+---------+
# | Margarita               |     48 |    33 |      28 |
# +-------------------------+--------+-------+---------+
# | Mixed Berry Smoothie    |     25 |    43 |      49 |
# +-------------------------+--------+-------+---------+
# | Orange Sherbet          |     22 |    33 |      23 |
# +-------------------------+--------+-------+---------+
# | Peach                   |     47 |    51 |      50 |
# +-------------------------+--------+-------+---------+
# | Pina Colada             |     34 |    57 |      37 |
# +-------------------------+--------+-------+---------+
# | Plum                    |     25 |    52 |      52 |
# +-------------------------+--------+-------+---------+
# | Pomegranate             |     40 |    30 |      51 |
# +-------------------------+--------+-------+---------+
# | Raspberry               |     43 |    47 |      42 |
# +-------------------------+--------+-------+---------+
# | Red Apple               |     53 |    45 |      40 |
# +-------------------------+--------+-------+---------+
# | Sizzling Cinnamon       |     35 |    54 |      38 |
# +-------------------------+--------+-------+---------+
# | Sour Cherry             |     50 |    42 |      30 |
# +-------------------------+--------+-------+---------+
# | Strawberry Cheesecake   |     45 |    26 |      35 |
# +-------------------------+--------+-------+---------+
# | Strawberry Daiquiri     |     26 |    37 |      34 |
# +-------------------------+--------+-------+---------+
# | Strawberry Jam          |     48 |    38 |      53 |
# +-------------------------+--------+-------+---------+
# | Sunkist Lemon           |     47 |    23 |      50 |
# +-------------------------+--------+-------+---------+
# | Sunkist Lime            |     32 |    26 |      50 |
# +-------------------------+--------+-------+---------+
# | Sunkist Orange          |     46 |    41 |      33 |
# +-------------------------+--------+-------+---------+
# | Sunkist Pink Grapefruit |     33 |    38 |      55 |
# +-------------------------+--------+-------+---------+
# | Sunkist Tangerine       |     22 |    49 |      30 |
# +-------------------------+--------+-------+---------+
# | Toasted Marshmallow     |     48 |    40 |      37 |
# +-------------------------+--------+-------+---------+
# | Top Banana              |     24 |    36 |      43 |
# +-------------------------+--------+-------+---------+
# | Tutti-Fruitti           |     35 |    43 |      54 |
# +-------------------------+--------+-------+---------+
# | Very Cherry             |     32 |    31 |      44 |
# +-------------------------+--------+-------+---------+
# | Watermelon              |     40 |    45 |      39 |
# +-------------------------+--------+-------+---------+
# | Wild Blackberry         |     26 |    34 |      33 |
# +-------------------------+--------+-------+---------+

# %% [markdown]
# ## Part G - The Recipes
#
# Fans of Jelly Bellies like to combine beans to form more complicated, unique flavors, such as "Apple Pie" and "Banana Split".
#
# These combinations are called "recipes" because they often combine multiple beans as "ingredients" to form a well-known food flavor.
#
# **Action:** Create an empty dictionary called `recipes`.

# %%
# Your implementation:

recipes = {}

# %% [markdown]
# A simple recipe, "Cola" calls for one(1) "Lemon Lime" bean and one(1) "Cinnamon" bean.
#
# We will add this recipe to `recipes`.  The name of the recipe "Cola" is the key and the value is... another dictionary where the key of the latter dictionary is the ingredient flavor and the value is the ingredient quantity.
#
# **Action:** Execute the following code:

# %%
recipes["Cola"] = { "Lemon Lime": 1, "Cinnamon": 1 }

# %% [markdown]
# **Actions:** Add the following recipes to `recipes` using the same convention as above:
#
# - "Apple Pie" is the result of eating 2 "Green Apple" beans and 1 "Cinnamon" bean.
# - "Key Lime Pie" is the result of eating 1 "Lemon Lime" bean and 1 "Toasted Marshmallow" bean.
# - "Pink Lemonade" is the result of eating 2 "Cotton Candy" beans and 2 "Sunkist Lemon" beans.
# - "Root Beer Float" is the result of eating 2 "A&W Root Beer" beans and 1 "A&W Cream Soda" bean.
# - "Cafe Mocha" is the result of eating 2 "Cappuccino" beans, 1 "Chocolate Pudding" bean, and 1 "French Vanilla" bean.
# - "Hot Chocolate" is the result of eating 1 "Toasted Marshmallow" bean and 1 "Chocolate Pudding" bean.
# - "Chocolate-Dipped Strawberries" is the result of eating 2 "Strawberry Daiquiri" beans and 1 "Chocolate Pudding" bean.
# - "S'mores" is the result of eating 1 "Caramel Corn" bean, 2 "Toasted Marshmallow" beans, and 1 "Chocolate Pudding" bean.
# - "Banana Split" is the result of eating 1 "Top Banana" bean, 1 "Chocolate Pudding" bean, 1 "Crushed Pineapple" bean, 1 "Strawberry Jam" bean, 1 "Very Cherry" bean, and 1 "French Vanilla" bean.

# %%
# Your implementation:

recipes["Apple Pie"] = {"Green Apple": 2, "Cinnamon": 1}
recipes["Key Lime Pie"] = {"Lemon Lime": 1, "Toasted Marshmallow": 1}
recipes["Pink Lemonade"] = {"Cotton Candy": 2, "Sunkist Lemon": 2}
recipes["Root Beer Float"] = {"A&W Root Beer": 2, "A&W Cream Soda": 1}
recipes["Cafe Mocha"] = {"Cappuccino": 2, "Chocolate Pudding": 1, "French Vanilla": 1}
recipes["Hot Chocolate"] = {"Toasted Marshmallow": 1, "Chocolate Pudding": 1}
recipes["Chocolate-Dipped Strawberries"] = {"Strawberry Daiquiri": 2, "Chocolate Pudding": 1}
recipes["S'mores"] = {"Caramel Corn": 1, "Toasted Marshmallow": 2, "Chocolate Pudding": 1}
recipes["Banana Split"] = {
    "Top Banana": 1, "Chocolate Pudding": 1, "Crushed Pineapple": 1,
    "Strawberry Jam": 1, "Very Cherry": 1, "French Vanilla": 1
}

# %% [markdown]
# Sitting around the table, the members have decided to make specific recipes from their beans.
#
# They will make the recipes, one at a time, in the following order:
#
# 1. Key Lime Pie
# 2. Apple Pie
# 3. Cafe Mocha
# 4. Cola
# 5. Hot Chocolate
# 6. Chocolate-Dipped Strawberries
# 7. Pink Lemonade
# 8. Root Beer Float
# 9. Banana Split
# 10. S'mores
#
# **Action:** Create a list called `recipeNamesInOrder` to hold the names of these recipes in the order.

# %%
# Your implementation:
recipeNamesInOrder = [
    "Key Lime Pie",
    "Apple Pie",
    "Cafe Mocha",
    "Cola",
    "Hot Chocolate",
    "Chocolate-Dipped Strawberries",
    "Pink Lemonade",
    "Root Beer Float",
    "Banana Split",
    "S'mores"
]

# %% [markdown]
# ## Part H - Initializing Recipe Counts
#
# In this part, you will create a complex data structure (a dictionary of dictionaries) to store the number of recipes that each member makes.
#
# **Actions:**
#
# - Create a dictionary called `recipeCounts`.
# - Use a combination of loops and existing variables (`memberNames`, `recipeNamesInOrder`, etc.) to dynamically create a dictionary of dictionaries where:
#     - The keys for the outer dictionary are the member names.
#     - The keys for the inner dictionary are the recipe names.
#     - The value for each member and each recipe is initialized to an integer value of zero (0).
# - Output `recipeCounts` to the screen to verify the data structure, keys, and values.

# %%
# Your implementation:
recipeCounts = {}

for member in memberNames:
    recipeCounts[member] = {recipe: 0 for recipe in recipeNamesInOrder}

print(recipeCounts)
# Out:
# {'Alex': {'Key Lime Pie': 0, 'Apple Pie': 0, 'Cafe Mocha': 0, 'Cola': 0, 'Hot Chocolate': 0, 'Chocolate-Dipped Strawberries': 0, 'Pink Lemonade': 0, 'Root Beer Float': 0, 'Banana Split': 0, "S'mores": 0}, 'Ben': {'Key Lime Pie': 0, 'Apple Pie': 0, 'Cafe Mocha': 0, 'Cola': 0, 'Hot Chocolate': 0, 'Chocolate-Dipped Strawberries': 0, 'Pink Lemonade': 0, 'Root Beer Float': 0, 'Banana Split': 0, "S'mores": 0}, 'Clara': {'Key Lime Pie': 0, 'Apple Pie': 0, 'Cafe Mocha': 0, 'Cola': 0, 'Hot Chocolate': 0, 'Chocolate-Dipped Strawberries': 0, 'Pink Lemonade': 0, 'Root Beer Float': 0, 'Banana Split': 0, "S'mores": 0}}

# %% [markdown]
# ## Part I - Making Recipes
#
# In this part, you will have the members "make" the recipes and "eat" the beans, dynamically.
#
# **Action:** Implement the following algorithm:
#
# - Iterate over each member
# - The current member tries to make each recipe, one at a time, in the order specified in `recipeNamesInOrder`.
# - Each recipe will require the exact ingredient flavors and quantity of beans.
# - Check if the recipe can be made before the member eats the beans.
# - If the recipe cannot be made, the member moves on to the next recipe.
# - Otherwise (if the recipe can be made):
#     - The recipe count is incremented by 1 for that recipe and that member, and
#     - The member eats the recipe (all the recipe's beans), so
#     - The program adjusts (subtracts) the flavor totals in the member's bag of beans accordingly.  You can't reuse an eaten bean!
# - After the last recipe in the order specified in `recipeNamesInOrder`, if the member has made at least one recipe successfully (any recipe), then repeat the order again from the beginning.
# - Otherwise (if the member went through the entire order without being able to make a single recipe), then:
#     - Stop making recipes (because this member cannot make any more recipes of any kind), and
#     - Move on to the next member (until there are no more members).
# - When finished, output `recipeCounts` to the screen to verify the data structure, keys, and values.

# %%
# Your implementation:

for member in memberNames:
    madeAtLeastOneRecipe = True
    while madeAtLeastOneRecipe:
        madeAtLeastOneRecipe = False  
        for recipeName in recipeNamesInOrder:
            recipeCanBeMade = True
            for ingredient, quantity in recipes[recipeName].items():
                if beanBags[member].get(ingredient, 0) < quantity:
                    recipeCanBeMade = False
                    break  
            
            # If the recipe can be made
            if recipeCanBeMade:
                madeAtLeastOneRecipe = True  
                recipeCounts[member][recipeName] += 1  
                for ingredient, quantity in recipes[recipeName].items():
                    beanBags[member][ingredient] -= quantity
                    
print(recipeCounts)
# Out:
# {'Alex': {'Key Lime Pie': 12, 'Apple Pie': 14, 'Cafe Mocha': 20, 'Cola': 13, 'Hot Chocolate': 12, 'Chocolate-Dipped Strawberries': 13, 'Pink Lemonade': 15, 'Root Beer Float': 13, 'Banana Split': 19, "S'mores": 12}, 'Ben': {'Key Lime Pie': 22, 'Apple Pie': 12, 'Cafe Mocha': 7, 'Cola': 18, 'Hot Chocolate': 6, 'Chocolate-Dipped Strawberries': 6, 'Pink Lemonade': 11, 'Root Beer Float': 17, 'Banana Split': 6, "S'mores": 6}, 'Clara': {'Key Lime Pie': 23, 'Apple Pie': 18, 'Cafe Mocha': 3, 'Cola': 18, 'Hot Chocolate': 2, 'Chocolate-Dipped Strawberries': 2, 'Pink Lemonade': 23, 'Root Beer Float': 26, 'Banana Split': 2, "S'mores": 2}}

# %% [markdown]
# ## Part J - Display Recipe Counts
#
# **Action:** Create a table showing the counts of each recipe made by each of the Jelly Belly Fan Club members.
#
# - Use the `tabulate` Python package to achieve column-based layout.
# - Column 1: Recipe (display the recipe name)
# - Column 2: Alex (display the number of recipes made of this recipe by Alex)
# - Column 3: Ben (display the number of recipes made of this recipe by Ben)
# - Column 4: Clara (display the number of recipes made of this recipe by Clara)
# - Do not use hard-coded strings for recipe names.
# - Do not use hard-coded strings for member names.

# %%
# Your implementation:

from tabulate import tabulate


table_data = []
for recipe in recipeNamesInOrder:  # Use the list of recipes to maintain the specified order
    row = [recipe]  # Start the row with the recipe name
    for member in memberNames:  # Iterate through each member
        row.append(recipeCounts[member][recipe])  # Add the count of the recipe made by the member
    table_data.append(row)

headers = ['Recipe', 'Alex', 'Ben', 'Clara']

print(tabulate(table_data, headers=headers, tablefmt='grid'))
# Out:
# +-------------------------------+--------+-------+---------+
# | Recipe                        |   Alex |   Ben |   Clara |
# +===============================+========+=======+=========+
# | Key Lime Pie                  |     12 |    22 |      23 |
# +-------------------------------+--------+-------+---------+
# | Apple Pie                     |     14 |    12 |      18 |
# +-------------------------------+--------+-------+---------+
# | Cafe Mocha                    |     20 |     7 |       3 |
# +-------------------------------+--------+-------+---------+
# | Cola                          |     13 |    18 |      18 |
# +-------------------------------+--------+-------+---------+
# | Hot Chocolate                 |     12 |     6 |       2 |
# +-------------------------------+--------+-------+---------+
# | Chocolate-Dipped Strawberries |     13 |     6 |       2 |
# +-------------------------------+--------+-------+---------+
# | Pink Lemonade                 |     15 |    11 |      23 |
# +-------------------------------+--------+-------+---------+
# | Root Beer Float               |     13 |    17 |      26 |
# +-------------------------------+--------+-------+---------+
# | Banana Split                  |     19 |     6 |       2 |
# +-------------------------------+--------+-------+---------+
# | S'mores                       |     12 |     6 |       2 |
# +-------------------------------+--------+-------+---------+

# %% [markdown]
# **Action:** Store the number of "Root Beer Float" recipes that Ben made in a variable called `numRootBeerFloats`.
#
# - Note: You may use hard-coded string values for list, tuple, or dictionary access.

# %%
# Your implementation:

numRootBeerFloats = recipeCounts['Ben']['Root Beer Float']

print("Number of 'Root Beer Float' recipes Ben made:", numRootBeerFloats)
# Out:
# Number of 'Root Beer Float' recipes Ben made: 17

# %% [markdown]
# **Action:** Use a loop to dynamically determine which member made the most "Pink Lemonade" recipes (and how many).
#
# - Store the correct member name value in `pinkLemonadeMaxMemberName`.
# - Store the correct number of recipes in `pinkLemonadeMaxNumber`.
# - You may use a hard-coded string for "Pink Lemonade", but not for member names.

# %%
# Your implementation:

pinkLemonadeMaxMemberName = ""
pinkLemonadeMaxNumber = 0

for member, recipes in recipeCounts.items():
    pinkLemonadeCount = recipes["Pink Lemonade"]
    
    if pinkLemonadeCount > pinkLemonadeMaxNumber:
        pinkLemonadeMaxMemberName = member
        pinkLemonadeMaxNumber = pinkLemonadeCount

# %% [markdown]
# **Action:** How many total recipes combined did all the members make?  Store the value in a variable called `totalRecipes`.

# %%
# Your implementation:
totalRecipes = 0

for member, recipes in recipeCounts.items():
    for recipe, count in recipes.items():
        totalRecipes += count

# %% [markdown]
# ## Part K - The Final Results
#
# To achieve points in this part, you must determine the correct numbers.
#
# **Action:** Execute the following code block to report the final results.

# %%
# print the final results

try:
    print ("All\tTotal Beans:\t\t\t\t{:,}".format (totalBeansAllMembers))
except NameError:
    print ("Error: totalBeansAllMembers not found.")
    
try:
    print ("All\tTotal Recipes Made:\t\t\t{:,}".format(totalRecipes))
except NameError:
    print ("Error: totalRecipes not found.")

try:
    print ("All\tTotal 'Lemon Line' Beans:\t\t{:,}".format (totalLemonLimeAllMembers))
except NameError:
    print ("Error: totalLemonLimeAllMembers not found.")

try:
    print ("Alex\tTotal Beans:\t\t\t\t{:,}".format(totalBeansAlex))
except NameError:
    print ("Error: totalBeansAlex not found.")

try:
    print ("Ben\tRoot Beer Float Recipes Made:\t\t{:,}".format (numRootBeerFloats))
except NameError:
    print ("Error: numRootBeerFloats not found.")
    
try:
    print ("\tMost Pink Lemonade Recipes Made:\t{:,} (by {})".format (pinkLemonadeMaxNumber, pinkLemonadeMaxMemberName))
except NameError:
    print ("Error: pinkLemonadeMaxNumber or pinkLemonadeMaxMemberName not found.")
# Out:
# All	Total Beans:				5,848
# All	Total Recipes Made:			373
# All	Total 'Lemon Line' Beans:		137
# Alex	Total Beans:				1,358
# Ben	Root Beer Float Recipes Made:		17
# 	Most Pink Lemonade Recipes Made:	23 (by Clara)
